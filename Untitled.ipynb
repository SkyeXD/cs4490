# %%
from ethnicolr import census_ln, pred_census_ln,pred_wiki_ln, pred_fl_reg_name, pred_fl_reg_ln,pred_nc_reg_name,pred_wiki_name
import pandas as pd
import numpy as np

paperdf = pd.read_csv('paper1.csv')
authordf = pd.read_csv('author1.csv')
matchdf = pd.read_csv('matching1.csv')
print(authordf)
# #pred_census_ln
# rdf2000 = pred_census_ln(authordf, 'lname', 2000)
# rdf2000['year'] = 2000
# rdf2010 = pred_census_ln(authordf, 'lname', 2010)
# rdf2010['year'] = 2010
# rdf = pd.concat([rdf2000, rdf2010])
# print(rdf)


# #pred_fl_reg_name
# print(authordf)
# pfrn = pred_fl_reg_name(authordf, 'lname','fname')
# pfrn['year'] = 2000
# pfrn.to_csv("pfrn.csv")


# #pred_fl_reg_ln

# pfrl = pred_fl_reg_ln(authordf, 'lname')
# pfrl['year'] = 2000
# pfrl.to_csv("pfrl.csv")


# #pred_nc_reg_name

# pnrn = pred_nc_reg_name(authordf, 'lname','fname')
# pnrn['year'] = 2000
# pnrn.to_csv("pnrn.csv")

# #pred_wiki_ln

# pwl = pred_wiki_ln(authordf, 'lname')
# pwl['year'] = 2000
# pwl.to_csv("pwl.csv")

# #pred_wiki_name

pwn = pred_wiki_name(authordf, 'lname','fname')
pwn['year'] = 2000
pwn.to_csv("pwn.csv")
# Out:
#      Unnamed: 0  id      fname       lname
# 0             0   0        Jim        Gray
# 1             1   1      Goetz      Graefe
# 2             2   2     Davood      Rafiei
# 3             3   3    Alberto   Mendelzon
# 4             4   4     Davood      Rafiei
# 5             5   5    Alberto   Mendelzon
# 6             6   6    Francis         Chu
# 7             7   7     Joseph     Halpern
# 8             8   8    Praveen    Seshadri
# 9             9   9     Prasan         Roy
# 10           10  10         S.    Seshadri
# 11           11  11         S.   Sudarshan
# 12           12  12   Siddhesh       Bhobe
# 13           13  13     Angela    Bonifati
# 14           14  14    Stefano        Ceri
# 15           15  15    Avigdor         Gal
# 16           16  16   Jonathan    Eckstein
# 17           17  17       Sara       Cohen
# 18           18  18     Werner        Nutt
# 19           19  19  Alexander  Serebrenik
# 20           20  20       Sara       Cohen
# ...
